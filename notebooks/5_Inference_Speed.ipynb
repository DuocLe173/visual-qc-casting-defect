# %% [markdown]
# # 🏭 Project 13: Visual Quality Control (QC)
# ## Notebook 5: Inference Speed Benchmark & Tối Ưu Hóa Ngưỡng (PR Curve)
#
# > **Tiêu chí Rubric:** 15 điểm
# > - Đo độ trễ (Latency per image) khi suy luận 1 ảnh đơn lẻ (ms/ảnh).
# > - Đo thông lượng (Throughput) theo Batch (16, 32, 64) $\rightarrow$ Tính FPS.
# > - Vẽ đồ thị Precision-Recall Curve và xác định ngưỡng Sweet Spot (ưu tiên Recall ≥ 95%).

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import precision_recall_curve, average_precision_score

print("Inference Speed Benchmark Ready!")
